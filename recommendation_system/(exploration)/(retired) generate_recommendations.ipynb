# %%
import pandas as pd
import numpy as np
import json

# %%
def collect_master_df():
    df = pd.read_csv('movielens_data_genome/movie_dataset_public_final/scores/glmer.csv')
    titles = df['item_id'].unique()
    return df, titles

# %%
def generate_random_watch_history(titles, lines, n = 20):
    titles = np.random.choice(titles,n)
    sample_user = {}
    for line in lines:
        if line['item_id'] in titles:
            sample_user[line['item_id']] = line['title']
    return sample_user

# %%
def generate_user_history_tag(sample_user, df):
    sample_user_matrix = []

    for movie in sample_user.keys():
        #skip if for some reason the movie does not contain all labels
        if len(df[df.item_id == movie]) != 1084:
            print(f'error {movie}')
        #if the movie contains all label values, obtain the tag vector from the main df
        else:
            matrix = list(df[df.item_id == movie].score.values)
            sample_user_matrix.append(matrix)

    #turning the list of lists into a matrix as a 2D array
    mat = np.array(sample_user_matrix)

    return mat

# %%
def generate_user_pref_vector(mat, f = '2-norm'):

    if f == '2-norm':
        matsq = mat**2
        agg = np.average(matsq, axis = 0)
        aggroot = agg**0.5

        return aggroot
    
    else:
        agg = []

        for col in mat.T:
            val = f(col)
            agg.append(val)
        
        return agg

# %%
def generate_master_matrix(df, titles):
    master_mat = []

    for movie in titles:
        if len(df[df.item_id == movie]) != 1084:
            print(f'error {movie}')

        else:
            matrix = list(df[df.item_id == movie].score.values)
            master_mat.append(matrix)
    master_mat = np.array(master_mat)

    return master_mat

# %%
def generate_user_movie_interest(master_mat, user_tag_interest, g = '2-norm'):
    if g == '2-norm':
        rows, _ = master_mat.shape
        dist = []
        for r in range(rows):
            d = np.linalg.norm(user_tag_interest-master_mat[r])
            dist.append(d)
        return dist
    
    else:
        dist = []
        for i in master_mat:
            val = g(user_tag_interest,i)
            dist.append(val)
        return dist

# %%
def read_metadata():
    lines = []
    for line in open('movielens_data_genome\\movie_dataset_public_final\\raw\\metadata_updated.json', 'r'):
        lines.append(json.loads(line))
    return lines

# %%
def generate_recommendation(dists, lines, titles, n_recs = 10, users = 1):
    if users == 1:
        dfresult = pd.DataFrame(titles, columns = ['movie_id'])
        dfresult['score1'] = dists[0]
        dfresult = dfresult.sort_values(by = ['score1'], ascending = False)
        dfrecommend = dfresult[0:n_recs]
        
        movie_titles = {}
        for line in lines:
            if line['item_id'] in dfrecommend.movie_id.values:

                movie_titles[line['item_id']] = line['title']
        
        dfrecommend['movie_title'] = dfrecommend['movie_id'].map(movie_titles)
        dfrecommend.reset_index(inplace = True)
        return dfrecommend
    
    if users == 2:
        dfresult = pd.DataFrame(titles, columns = ['movie_id'])
        dfresult['score1'] = dists[0]
        dfresult['score2'] = dists[1]

        dfresult['average'] = (dfresult['score1'] + dfresult['score2'])/2
        dfresult['dev'] = ((dfresult['score1']-dfresult['average'])**2) + ((dfresult['score2'] - dfresult['average'])**2)
        dfresult = dfresult.sort_values(by = ['average'], ascending = False)

        dfrecommend = dfresult[0:2*n_recs]
        dfrecommend = dfrecommend.sort_values(by= ['dev'], ascending = True)
        dfrecommend = dfrecommend[0:n_recs]

        movie_titles = {}
        for line in lines:
            if line['item_id'] in dfrecommend.movie_id.values:

                movie_titles[line['item_id']] = line['title']
        
        dfrecommend['movie_title'] = dfrecommend['movie_id'].map(movie_titles)
        dfrecommend.reset_index(inplace = True)
        return dfrecommend

# %%
df, titles = collect_master_df()
master_mat = generate_master_matrix(df, titles)
lines = read_metadata()

# %%
sample_user1 = generate_random_watch_history(titles, lines,10)
mat1 = generate_user_history_tag(sample_user1, df)
agg1 = generate_user_pref_vector(mat1, f = f)
dist1 = generate_user_movie_interest(master_mat, agg1)
dfrecommend1 = generate_recommendation([dist1], lines, titles, n_recs = 20, users = 1)
# Out:
# C:\Users\Praveen Bandla\AppData\Local\Temp\ipykernel_17848\4229598789.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfrecommend['movie_title'] = dfrecommend['movie_id'].map(movie_titles)

# %%
sample_user2 = generate_random_watch_history(titles, lines,10)
mat2 = generate_user_history_tag(sample_user2, df)
agg2 = generate_user_pref_vector(mat2, f = f)
dist2 = generate_user_movie_interest(master_mat, agg2)
dfrecommend2 = generate_recommendation([dist2], lines, titles, n_recs = 20, users = 1)
# Out:
# C:\Users\Praveen Bandla\AppData\Local\Temp\ipykernel_17848\4229598789.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfrecommend['movie_title'] = dfrecommend['movie_id'].map(movie_titles)

# %%
sample_user3 = generate_random_watch_history(titles, lines,10)
mat3 = generate_user_history_tag(sample_user3, df)
agg3 = generate_user_pref_vector(mat3, f = '2-norm')
dist3 = generate_user_movie_interest(master_mat, agg3)
dfrecommend3 = generate_recommendation([dist3], lines, titles, n_recs = 20, users = 1)
# Out:
# C:\Users\Praveen Bandla\AppData\Local\Temp\ipykernel_17848\4229598789.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfrecommend['movie_title'] = dfrecommend['movie_id'].map(movie_titles)

# %%
def f(a):
    result = 0
    for val in a:
        result+= val**0.5
    
    result = result/np.size(a)
    result = result**2
    return result

# %%
dfrecommend1
# Out:
#     index  movie_id    score1  \
# 0    2614      2959  9.549704
# 1     977      1089  9.394981
# 2    2267      2571  9.271626
# 3     280       296  9.269817
# 4    1059      1196  9.187138
# 5    5149      6016  9.085729
# 6     302       318  9.047456
# 7    2037      2329  9.005067
# 8     245       260  8.998636
# 9    6140      7415  8.995307
# 10   3716      4226  8.979253
# 11   2522      2858  8.961773
# 12    338       356  8.937530
# 13   4294      4878  8.893360
# 14    501       527  8.870564
# 15   6599      8718  8.821075
# 16   1057      1193  8.724544
# 17   1075      1213  8.713398
# 18     49        50  8.621597
# 19   1061      1198  8.611472
#
#                                           movie_title
# 0                                   Fight Club (1999)
# 1                               Reservoir Dogs (1992)
# 2                                  Matrix, The (1999)
# 3                                 Pulp Fiction (1994)
# 4   Star Wars: Episode V - The Empire Strikes Back...
# 5                 City of God (Cidade de Deus) (2002)
# 6                    Shawshank Redemption, The (1994)
# 7                           American History X (1998)
# 8           Star Wars: Episode IV - A New Hope (1977)
# 9                               Late Show, The (1977)
# 10                                     Memento (2000)
# 11                             American Beauty (1999)
# 12                                Forrest Gump (1994)
# 13                                Donnie Darko (2001)
# 14                            Schindler's List (1993)
# 15                              Snake Pit, The (1948)
# 16             One Flew Over the Cuckoo's Nest (1975)
# 17                                  Goodfellas (1990)
# 18                         Usual Suspects, The (1995)
# 19  Raiders of the Lost Ark (Indiana Jones and the...

# %%
dfrecommend2
# Out:
#     index  movie_id    score1  \
# 0    2267      2571  9.600046
# 1    2614      2959  9.558086
# 2    1059      1196  9.527170
# 3     977      1089  9.381920
# 4     245       260  9.346555
# 5     280       296  9.180485
# 6     302       318  9.034652
# 7    6140      7415  9.034473
# 8    1072      1210  9.028406
# 9     338       356  8.968013
# 10   1061      1198  8.940016
# 11   8313     58559  8.920255
# 12   5149      6016  8.918276
# 13   2037      2329  8.909047
# 14   3716      4226  8.870184
# 15   4294      4878  8.794150
# 16   1100      1240  8.727016
# 17   6539      8587  8.719514
# 18   9036     79132  8.705379
# 19    501       527  8.681455
#
#                                           movie_title
# 0                                  Matrix, The (1999)
# 1                                   Fight Club (1999)
# 2   Star Wars: Episode V - The Empire Strikes Back...
# 3                               Reservoir Dogs (1992)
# 4           Star Wars: Episode IV - A New Hope (1977)
# 5                                 Pulp Fiction (1994)
# 6                    Shawshank Redemption, The (1994)
# 7                               Late Show, The (1977)
# 8   Star Wars: Episode VI - Return of the Jedi (1983)
# 9                                 Forrest Gump (1994)
# 10  Raiders of the Lost Ark (Indiana Jones and the...
# 11                            Dark Knight, The (2008)
# 12                City of God (Cidade de Deus) (2002)
# 13                          American History X (1998)
# 14                                     Memento (2000)
# 15                                Donnie Darko (2001)
# 16                             Terminator, The (1984)
# 17                   Mayor of the Sunset Strip (2003)
# 18                                   Inception (2010)
# 19                            Schindler's List (1993)

# %%
dfrecommend3
# Out:
#     index  movie_id    score1  \
# 0    1059      1196  8.893580
# 1    2267      2571  8.822033
# 2     245       260  8.786159
# 3    2614      2959  8.703877
# 4     280       296  8.488547
# 5    1072      1210  8.484241
# 6     977      1089  8.462659
# 7     338       356  8.379094
# 8     302       318  8.254676
# 9    1061      1198  8.250301
# 10    501       527  8.209940
# 11   1100      1240  8.190250
# 12   8313     58559  8.157315
# 13   5149      6016  8.116942
# 14   4392      4993  8.088604
# 15   2037      2329  8.085615
# 16    554       589  8.079560
# 17   6140      7415  8.061167
# 18   3716      4226  8.051229
# 19   5101      5952  8.047841
#
#                                           movie_title
# 0   Star Wars: Episode V - The Empire Strikes Back...
# 1                                  Matrix, The (1999)
# 2           Star Wars: Episode IV - A New Hope (1977)
# 3                                   Fight Club (1999)
# 4                                 Pulp Fiction (1994)
# 5   Star Wars: Episode VI - Return of the Jedi (1983)
# 6                               Reservoir Dogs (1992)
# 7                                 Forrest Gump (1994)
# 8                    Shawshank Redemption, The (1994)
# 9   Raiders of the Lost Ark (Indiana Jones and the...
# 10                            Schindler's List (1993)
# 11                             Terminator, The (1984)
# 12                            Dark Knight, The (2008)
# 13                City of God (Cidade de Deus) (2002)
# 14  Lord of the Rings: The Fellowship of the Ring,...
# 15                          American History X (1998)
# 16                  Terminator 2: Judgment Day (1991)
# 17                              Late Show, The (1977)
# 18                                     Memento (2000)
# 19      Lord of the Rings: The Two Towers, The (2002)

# %%
dfrecommend12 = generate_recommendation([dist1,dist2], lines, titles, n_recs = 10, users = 2)
dfrecommend12
# Out:
#    index  movie_id    score1    score2   average       dev  \
# 0   2614      2959  9.549704  9.558086  9.553895  0.000035
# 1    302       318  9.047456  9.034652  9.041054  0.000082
# 2    977      1089  9.394981  9.381920  9.388451  0.000085
# 3    338       356  8.937530  8.968013  8.952771  0.000465
# 4   6140      7415  8.995307  9.034473  9.014890  0.000767
# 5   1075      1213  8.713398  8.661880  8.687639  0.001327
# 6    280       296  9.269817  9.180485  9.225151  0.003990
# 7   2037      2329  9.005067  8.909047  8.957057  0.004610
# 8   4294      4878  8.893360  8.794150  8.843755  0.004921
# 9   3716      4226  8.979253  8.870184  8.924718  0.005948
#
#                         movie_title
# 0                 Fight Club (1999)
# 1  Shawshank Redemption, The (1994)
# 2             Reservoir Dogs (1992)
# 3               Forrest Gump (1994)
# 4             Late Show, The (1977)
# 5                 Goodfellas (1990)
# 6               Pulp Fiction (1994)
# 7         American History X (1998)
# 8               Donnie Darko (2001)
# 9                    Memento (2000)

# %%
dfrecommend13 = generate_recommendation([dist1,dist3], lines, titles, n_recs = 10, users = 2)
dfrecommend13
# Out:
#    index  movie_id    score1    score2   average       dev  \
# 0   1072      1210  8.596752  8.484241  8.540496  0.006329
# 1    245       260  8.998636  8.786159  8.892397  0.022573
# 2   1059      1196  9.187138  8.893580  9.040359  0.043088
# 3   1061      1198  8.611472  8.250301  8.430887  0.065222
# 4   8313     58559  8.585096  8.157315  8.371205  0.091498
# 5   2267      2571  9.271626  8.822033  9.046830  0.101067
# 6    338       356  8.937530  8.379094  8.658312  0.155925
# 7    501       527  8.870564  8.209940  8.540252  0.218212
# 8    280       296  9.269817  8.488547  8.879182  0.305191
# 9    302       318  9.047456  8.254676  8.651066  0.314251
#
#                                          movie_title
# 0  Star Wars: Episode VI - Return of the Jedi (1983)
# 1          Star Wars: Episode IV - A New Hope (1977)
# 2  Star Wars: Episode V - The Empire Strikes Back...
# 3  Raiders of the Lost Ark (Indiana Jones and the...
# 4                            Dark Knight, The (2008)
# 5                                 Matrix, The (1999)
# 6                                Forrest Gump (1994)
# 7                            Schindler's List (1993)
# 8                                Pulp Fiction (1994)
# 9                   Shawshank Redemption, The (1994)

# %%
dfrecommend23 = generate_recommendation([dist2,dist3], lines, titles, n_recs = 10, users = 2)
dfrecommend23
# Out:
#    index  movie_id    score1    score2   average       dev  \
# 0    501       527  8.681455  8.209940  8.445697  0.111163
# 1   1100      1240  8.727016  8.190250  8.458633  0.144059
# 2   1072      1210  9.028406  8.484241  8.756324  0.148058
# 3    554       589  8.632875  8.079560  8.356217  0.153079
# 4    245       260  9.346555  8.786159  9.066357  0.157022
# 5    338       356  8.968013  8.379094  8.673554  0.173413
# 6   1059      1196  9.527170  8.893580  9.210375  0.200718
# 7   1061      1198  8.940016  8.250301  8.595159  0.237853
# 8    280       296  9.180485  8.488547  8.834516  0.239389
# 9   2522      2858  8.681158  7.987080  8.334119  0.240873
#
#                                          movie_title
# 0                            Schindler's List (1993)
# 1                             Terminator, The (1984)
# 2  Star Wars: Episode VI - Return of the Jedi (1983)
# 3                  Terminator 2: Judgment Day (1991)
# 4          Star Wars: Episode IV - A New Hope (1977)
# 5                                Forrest Gump (1994)
# 6  Star Wars: Episode V - The Empire Strikes Back...
# 7  Raiders of the Lost Ark (Indiana Jones and the...
# 8                                Pulp Fiction (1994)
# 9                             American Beauty (1999)
